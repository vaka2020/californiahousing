# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import fetch_california_housing

# %%
housing=fetch_california_housing()

# %%
housing.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'feature_names', 'DESCR'])

# %%
print(housing["DESCR"])
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 20640
#
# :Number of Attributes: 8 numeric, predictive attributes and the target
#
# :Attribute Information:
#     - MedInc        median income in block group
#     - HouseAge      median house age in block group
#     - AveRooms      average number of rooms per household
#     - AveBedrms     average number of bedrooms per household
#     - Population    block group population
#     - AveOccup      average number of household members
#     - Latitude      block group latitude
#     - Longitude     block group longitude
#
# :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# ...

# %%
print(housing.data)
# Out:
# [[   8.3252       41.            6.98412698 ...    2.55555556
#     37.88       -122.23      ]
#  [   8.3014       21.            6.23813708 ...    2.10984183
#     37.86       -122.22      ]
#  [   7.2574       52.            8.28813559 ...    2.80225989
#     37.85       -122.24      ]
#  ...
#  [   1.7          17.            5.20554273 ...    2.3256351
#     39.43       -121.22      ]
#  [   1.8672       18.            5.32951289 ...    2.12320917
#     39.43       -121.32      ]
#  [   2.3886       16.            5.25471698 ...    2.61698113
#     39.37       -121.24      ]]

# %%
print(housing.target)
# Out:
# [4.526 3.585 3.521 ... 0.923 0.847 0.894]

# %%
print(housing.feature_names)
# Out:
# ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']

# %%
print(housing.target_names)
# Out:
# ['MedHouseVal']

# %% [markdown]
# ## Preparing the Dataset

# %%
dataset=pd.DataFrame(housing.data, columns=housing.feature_names)

# %%
dataset
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
dataset.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
dataset["price"]=housing.target

# %%
dataset.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
dataset.info
# Out:
# <bound method DataFrame.info of        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
# ...

# %%
## Statistics of the Dataset
dataset.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude         price
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
## checking missinng values
dataset.isnull()
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0       False     False     False      False       False     False     False
# 1       False     False     False      False       False     False     False
# 2       False     False     False      False       False     False     False
# 3       False     False     False      False       False     False     False
# 4       False     False     False      False       False     False     False
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635   False     False     False      False       False     False     False
# 20636   False     False     False      False       False     False     False
# 20637   False     False     False      False       False     False     False
# 20638   False     False     False      False       False     False     False
# 20639   False     False     False      False       False     False     False
#
#        Longitude  price
# ...

# %%
dataset.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# price         0
# dtype: int64

# %%
## Exploratory Data Analysis
## Find corelation
dataset.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# price       0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude     price
# MedInc     -0.079809  -0.015176  0.688075
# HouseAge    0.011173  -0.108197  0.105623
# AveRooms    0.106389  -0.027540  0.151948
# AveBedrms   0.069721   0.013344 -0.046701
# ...

# %%
pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
sns.pairplot(dataset)

# %%
plt.scatter(dataset["MedInc"], dataset["price"])
plt.xlabel("Median Income")
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %% [markdown]
# MedInc	HouseAge	AveRooms	AveBedrms	Population	AveOccup	Latitude	Longitude

# %%
sns.regplot(x="MedInc", y="price", data=dataset)
# Out:
# <Axes: xlabel='MedInc', ylabel='price'>

# %%
sns.regplot(x="HouseAge", y="price", data=dataset)
# Out:
# <Axes: xlabel='HouseAge', ylabel='price'>

# %%
sns.regplot(x="AveRooms", y="price", data=dataset)
# Out:
# <Axes: xlabel='AveRooms', ylabel='price'>

# %%
sns.regplot(x="AveBedrms", y="price", data=dataset)
# Out:
# <Axes: xlabel='AveBedrms', ylabel='price'>

# %%
sns.regplot(x="Population", y="price", data=dataset)
# Out:
# <Axes: xlabel='Population', ylabel='price'>

# %%
sns.regplot(x="AveOccup", y="price", data=dataset)
# Out:
# <Axes: xlabel='AveOccup', ylabel='price'>

# %%
sns.regplot(x="Latitude", y="price", data=dataset)
# Out:
# <Axes: xlabel='Latitude', ylabel='price'>

# %%
sns.regplot(x="Longitude", y="price", data=dataset)
# Out:
# <Axes: xlabel='Longitude', ylabel='price'>

# %%
## Identify Idependent and dependent variables
X=dataset.iloc[:,:-1]  # selects all rows and columns
Y=dataset.iloc[:, -1]  # selects the values of last column

# %%
X.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
Y
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: price, Length: 20640, dtype: float64

# %%
# Train test & Split
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test=train_test_split(X, Y, test_size=0.20, random_state=63)

# %%
X_train
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 1199   1.7885      32.0  5.073973   1.021918       911.0  2.495890     39.37
# 7962   2.8750      35.0  4.582902   1.129534      1166.0  3.020725     33.87
# 4296   3.0357      38.0  4.072165   1.417526       664.0  3.422680     34.09
# 10925  4.0231      31.0  4.003322   0.930233      1476.0  4.903654     33.75
# 18872  5.2957      18.0  6.483932   1.019849      3205.0  3.029301     38.09
# ...       ...       ...       ...        ...         ...       ...       ...
# 288    3.8750      49.0  4.933702   0.977901       468.0  2.585635     37.78
# 2386   2.3359      24.0  4.994083   1.094675      1564.0  3.084813     37.10
# 139    6.3302      39.0  7.540000   1.068000      1265.0  2.530000     37.82
# 11380  5.5312      27.0  5.623377   0.983766      1115.0  3.620130     33.68
# 5164   1.9655      40.0  4.478469   1.108453      2357.0  3.759171     33.95
#
#        Longitude
# 1199     -121.70
# ...

# %%
X_test
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 11110  3.2303      13.0  3.664352   1.097222      1672.0  3.870370     33.85
# 363    4.0313      36.0  6.330275   0.963303       299.0  2.743119     37.75
# 13324  1.9659      50.0  4.333333   0.972789       590.0  4.013605     34.06
# 10769  4.1372      33.0  4.911202   1.072404      1621.0  2.214481     33.66
# 7833   2.9531      28.0  4.341753   1.098068      3013.0  4.476969     33.91
# ...       ...       ...       ...        ...         ...       ...       ...
# 6405   4.7159      36.0  6.561576   1.068966       648.0  3.192118     34.13
# 19062  3.4031      15.0  5.286797   1.069264      2175.0  2.353896     38.30
# 17244  2.3681      39.0  3.922460   1.018717      1404.0  3.754011     34.43
# 3008   2.7659      10.0  5.364193   1.111706      4163.0  3.185157     35.28
# 6183   3.0441      20.0  4.493250   1.076843      2296.0  2.384216     34.09
#
#        Longitude
# 11110    -117.89
# ...

# %%
# Standardization --> to covert the data in values in to same units
from sklearn.preprocessing import StandardScaler
Scaler=StandardScaler()
X_train=Scaler.fit_transform(X_train)
X_test=Scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-1.09985533,  0.26502215, -0.13937482, ..., -0.05241721,
#          1.74478236, -1.05910188],
#        [-0.52545971,  0.50353342, -0.3308683 , ..., -0.00439622,
#         -0.82610343,  0.69123003],
#        [-0.44050308,  0.74204469, -0.53003037, ...,  0.03238158,
#         -0.723268  ,  0.64634972],
#        ...,
#        [ 1.30118708,  0.82154845,  0.82225419, ..., -0.04929627,
#          1.02026   , -1.30843691],
#        [ 0.87878294, -0.13249663,  0.07486564, ...,  0.05044767,
#         -0.91491585,  0.81091084],
#        [-1.00628144,  0.9010522 , -0.37159188, ...,  0.06316953,
#         -0.78870873,  0.64136302]], shape=(16512, 8))

# %%
X_test
# Out:
# array([[-0.33762468, -1.24554922, -0.68905736, ...,  0.073344  ,
#         -0.83545211,  0.84083104],
#        [ 0.0858368 ,  0.58303718,  0.35052122, ..., -0.02979643,
#          0.98753964, -1.2785167 ],
#        [-1.00606998,  1.69608977, -0.42818759, ...,  0.08644963,
#         -0.73729101,  0.96549856],
#        ...,
#        [-0.79344051,  0.82154845, -0.58840796, ...,  0.06269741,
#         -0.56434052, -0.04680166],
#        [-0.58313717, -1.48406049, -0.02620326, ...,  0.01064881,
#         -0.1670218 ,  0.28232058],
#        [-0.43606229, -0.68902293, -0.36582788, ..., -0.06263511,
#         -0.723268  ,  0.83085764]], shape=(4128, 8))

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LinearRegression
Regression=LinearRegression()
Regression
# Out:
# LinearRegression()

# %%
Regression.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Regression.coef_
# Out:
# array([ 0.82504807,  0.11851436, -0.27753215,  0.32044   , -0.0089115 ,
#        -0.0447337 , -0.89396184, -0.86596103])

# %%
Regression.intercept_
# Out:
# np.float64(2.069433719113366)

# %%
## on which parameters the model has been trained
Regression.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'positive': False,
#  'tol': 1e-06}

# %%
## Prediction with test data
predict_y=Regression.predict(X_test)
predict_y
# Out:
# array([1.8481359 , 2.26028524, 1.30474013, ..., 2.16722884, 1.31157843,
#        1.63939082], shape=(4128,))

# %%
plt.scatter(Y_test, predict_y)

# %%
## Error
error=Y_test-predict_y
print(error)
error.sum()
# Out:
# 11110    0.164864
# 363     -0.305285
# 13324   -0.447740
# 10769    0.284269
# 7833    -0.603049
#            ...
# 6405     1.332174
# 19062    0.225907
# 17244    0.246771
# 3008    -0.536578
# 6183     0.214609
# Name: price, Length: 4128, dtype: float64
# np.float64(-19.39719011853814)

# %%
## plot error
sns.displot(error, kind="kde")

# %%
# plot scatterplot with respect to prediction and error
plt.scatter(error, predict_y)
plt.xlabel("error")
plt.ylabel("prediction")
# Out:
# Text(0, 0.5, 'prediction')

# %%
# performance metrics
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

print(mean_squared_error(predict_y, Y_test))
print(mean_absolute_error(predict_y, Y_test))
print(np.sqrt(mean_squared_error(predict_y, Y_test)))
# Out:
# 0.5184656273199938
# 0.527024338757807
# 0.7200455730854776

# %% [markdown]
# ## R Square and Adjusted R square

# %%
from sklearn.metrics import r2_score
r2_score=r2_score(Y_test, predict_y)
print(r2_score)
# Out:
# 0.6212797863430707

# %%
# calculate adjusted r^2
# adjusted_r^2=1-(1-r2_score)*len(Y_test)-1)/(len(Y_test)-X_test.shape[1]-1)
1-(1-r2_score)*(len(Y_test)-1)/(len(Y_test)-X_test.shape[1]-1)
# Out:
# 0.6205442287540308

# %% [markdown]
# ## Prediction on New Data

# %%
Regression.predict(Scaler.transform(housing.data[0].reshape(1, -1)))
# Out:
# c:\Users\chiru\Desktop\endtoendMLprojects\californiahousing\env\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([4.13381032])

# %%
print(housing.target[0])
# Out:
# 4.526

# %% [markdown]
# ## Model Serialization

# %%
# Pickling the model
import pickle
pickle.dump(Regression, open("regression.pkl", "wb"))
predict_model=pickle.load(open("regression.pkl", "rb"))

# %%
predict_model.predict(Scaler.transform(housing.data[0].reshape(1, -1)))
# Out:
# c:\Users\chiru\Desktop\endtoendMLprojects\californiahousing\env\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([4.13381032])
